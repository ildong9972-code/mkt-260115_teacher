# %%
# !pip install openpyxl
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: openpyxl in /Users/admin/Library/Python/3.9/lib/python/site-packages (3.1.5)
# Requirement already satisfied: et-xmlfile in /Users/admin/Library/Python/3.9/lib/python/site-packages (from openpyxl) (2.0.0)

# %%
# !pip install kiwipiepy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: kiwipiepy in /Users/admin/Library/Python/3.9/lib/python/site-packages (0.22.2)
# Requirement already satisfied: kiwipiepy-model<0.23,>=0.22 in /Users/admin/Library/Python/3.9/lib/python/site-packages (from kiwipiepy) (0.22.1)
# Requirement already satisfied: tqdm in /Users/admin/Library/Python/3.9/lib/python/site-packages (from kiwipiepy) (4.67.1)
# Requirement already satisfied: numpy in /Users/admin/Library/Python/3.9/lib/python/site-packages (from kiwipiepy) (2.0.2)

# %%
from openpyxl import load_workbook
from kiwipiepy import Kiwi

src = r"naverkeyword.xlsx"
out = r"naverkeyword_result.xlsx"

wb = load_workbook(src)
ws = wb.active

def find_col_by_header(ws, keywords, header_row = 1) :
    # keywords = ["연관키워드", "월간검색수 (PC)", "월간검색수 (MOBILE)", ... , "월평균노출 광고수"]
    for col in range(1, ws.max_column + 1) :
        v = ws.cell(row=header_row, column=col).value
        if not v :
            continue
        s = str(v).replace(" ", "") # 월간검색수 (PC) -> 월간검색수(PC)

        ok = True
        for kw in keywords :
            if kw.replace(" ", "") not in s :
                ok = False
                break
        if ok :
            return col
    return None
    
print(ws)
# Out:
# <Worksheet "sheet">
